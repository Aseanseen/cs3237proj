# %%
import csv

# %%
dev1 = pd.read_csv("out_E_53_3A_A1.csv")
dev2 = pd.read_csv("out_E_B6_DC_03.csv")
dev2
# Out:
#          Timestamp  accX_:3A:A1  accY_:3A:A1  accZ_:3A:A1  magX_:3A:A1  \
# 0     1.635152e+09     0.000000     0.000000     0.000000     0.000000
# 1     1.635152e+09     1.506348     1.190430     0.786133    -1.182556
# 2     1.635152e+09     1.487305     1.154297     0.771484    -3.974915
# 3     1.635152e+09     1.520996     1.267578     0.870605     1.136780
# 4     1.635152e+09     1.506836     1.163574     0.808594    -2.304077
# ...            ...          ...          ...          ...          ...
# 1401  1.635153e+09          NaN          NaN          NaN          NaN
# 1402  1.635153e+09          NaN          NaN          NaN          NaN
# 1403  1.635153e+09          NaN          NaN          NaN          NaN
# 1404  1.635153e+09          NaN          NaN          NaN          NaN
# 1405  1.635153e+09          NaN          NaN          NaN          NaN
#
#       magY_:3A:A1  magZ_:3A:A1  gyroX_:3A:A1  gyroY_:3A:A1  gyroZ_:3A:A1  ...  \
# ...
